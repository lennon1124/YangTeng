# %% [markdown]
# - Update: 2023.03.06
#
# # 0. 配置参数
#
# - `calculate`：what the fuck

# %%
calculate = '../../file/计算表-【每日断货汇报】US-Ebay 20230303.xlsx'

out = '../../file/Lennon_断货汇报_筛选好的断货SKU_NOW().xlsx'

# %%
import pandas as pd

# %%
df = pd.read_excel(calculate, sheet_name='附_1统计源（含新品、清仓、新品成长）', header=3, usecols=[i for i in range(1, 13)])

df
# Out:
#          No.         MRP SKU  目标\n周销   品类  Level      状态变更日  状态 运营备注  未售出周数  \
# 0          1    USTBC40007-C   38.20  TBC   TOP1 2022-03-28  老品   暴涨      0
# 1          2      USWR645FRU   29.16   WR   TOP1 2022-01-31  老品  NaN      0
# 2          3   USBCB72928BLR    7.27   BC   TOP1 2021-09-27  老品   暴涨      0
# 3          4    USBDA04108-2   12.99  BDA   TOP1 2020-06-28  老品  NaN      0
# 4          5      USGSM3570T   40.00   GS  TOP10 2022-03-14  老品  NaN      0
# ...      ...             ...     ...  ...    ...        ...  ..  ...    ...
# 51084  51085  USICK81600-4-C    1.50  ICK  TOP20 2023-02-20  新品  NaN      0
# 51085  51086  USICK84900-4-C    1.00  ICK     普通 2023-02-20  新品  NaN      0
# 51086  51087       USIM81510    6.00   IM  TOP10 2023-02-20  新品  NaN      0
# 51087  51088      USWR48974N    0.25   WR     普通 2023-02-20  老品  NaN     12
# 51088  51089       USHB1171E    0.25   HB     普通 2023-02-20  老品  NaN     12
#
#        注意事项   在库   在途
# 0       NaN  390   58
# 1       NaN  520    0
# 2       NaN   37   36
# 3       NaN  314   38
# 4      更新周销  111  183
# ...     ...  ...  ...
# 51084   NaN    0   21
# 51085   NaN    0   14
# 51086   NaN    0   72
# 51087   NaN   48    0
# 51088   NaN   24    0
#
# [51089 rows x 12 columns]

# %%
df = df[(df['在库']==0) & (df['在途']==0) & (df['Level']!='普通')][['MRP SKU', 'Level', '目标\n周销', '在途']]

df
# Out:
#                MRP SKU  Level  目标\n周销  在途
# 311        USSGTE005-C  TOP20    6.73   0
# 526       USACH11410-C  TOP10    4.00   0
# 568       USRAD13068-C  TOP20    2.50   0
# 894         USWIM03053  TOP20    0.12   0
# 957         USIM30370T  TOP20    2.92   0
# ...                ...    ...     ...  ..
# 50189  USFFCHPO007S-YC  TOP20    1.00   0
# 50541  USFFDOPO005T-YC  TOP20    1.00   0
# 50551  USFFDOOE003S-YC  TOP20    3.00   0
# 50556  USFFCHPO004S-YC  TOP20    0.33   0
# 50559  USFFCHOE003S-YC  TOP20    3.00   0
#
# [174 rows x 4 columns]

# %%
import datetime

writer = pd.ExcelWriter(out.replace('NOW()', datetime.datetime.now().strftime("%Y%m%d_%H%M%S")))
df.to_excel(writer, index=False)
writer.close()
